# %% [markdown]
# # Notebook 03 — Centralized Imports
#
# This notebook serves as the central import hub for the Construction Delay Risk Prediction System (CDRPS).
# Its purpose is to ensure that all modules inside the `src` directory load correctly and consistently across the entire project.
#
# By consolidating imports here, we achieve:
#
# - A single place to verify that the project structure is recognized by Python
# - Cleaner downstream notebooks (no repeated import blocks)
# - Faster debugging when modules change
# - A stable environment for all ingestion, validation, preparation, and modeling steps
#
# This notebook also configures the Python path so that the `src` directory is always discoverable, regardless of where the notebook is executed from.
# Once this notebook runs successfully, all other notebooks in the pipeline can rely on these imports without modification.

# %%
import sys
import os

# Determine project root (one level above the notebooks folder)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add to Python path if not already present
if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to Python path:", project_root)
# Out:
# Project root added to Python path: c:\Users\olive\Desktop\My ML Material\CONSTRUCTION DELAY RISK PREDICTION SYSTEM\CDRPS

# %%
import pandas as pd
import numpy as np

# %%
from src.ingestion.file_loader import load_file, preview_data

# %%
from src.validation.schema_validator import run_validation

# %%
from src.preparation.cleaning import clean_dataset

# %%
from src.preparation.encoding import encode_categorical, scale_numerical

# %%
from src.preparation.splitter import split_dataset

# %%
print("All modules imported successfully.")
# Out:
# All modules imported successfully.
